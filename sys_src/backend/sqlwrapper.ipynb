# %%
# !pip install rdflib
# !pip install sparqlwrapper

from SPARQLWrapper import SPARQLWrapper, JSON
graphdb_url = 'http://localhost:7200/repositories/movies'

sparql = SPARQLWrapper(graphdb_url)
sparql.setReturnFormat(JSON)

sparql.setQuery("""
    PREFIX imdb: <http://academy.ontotext.com/imdb/>
    PREFIX schema: <http://schema.org/>

    SELECT * { 
        # ?movie a imdb:ColorMovie ;
           schema:name ?movieName ;
           schema:commentCount ?commentCount .
    }   
    ORDER BY DESC(?commentCount)
    LIMIT 5
""")

try:
    ret = sparql.queryAndConvert()
    for r in ret["results"]["bindings"]:
        print(r)
except Exception as e:
    print(e)
# Out:
# {'movie': {'type': 'uri', 'value': 'http://academy.ontotext.com/imdb/title/TheDarkKnightRises'}, 'movieName': {'type': 'literal', 'value': 'The Dark Knight Rises'}, 'commentCount': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '813'}}
# {'movie': {'type': 'uri', 'value': 'http://academy.ontotext.com/imdb/title/Prometheus'}, 'movieName': {'type': 'literal', 'value': 'Prometheus'}, 'commentCount': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '775'}}
# {'movie': {'type': 'uri', 'value': 'http://academy.ontotext.com/imdb/title/DjangoUnchained'}, 'movieName': {'type': 'literal', 'value': 'Django Unchained'}, 'commentCount': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '765'}}
# {'movie': {'type': 'uri', 'value': 'http://academy.ontotext.com/imdb/title/Skyfall'}, 'movieName': {'type': 'literal', 'value': 'Skyfall'}, 'commentCount': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '750'}}
# {'movie': {'type': 'uri', 'value': 'http://academy.ontotext.com/imdb/title/MadMaxFuryRoad'}, 'movieName': {'type': 'literal', 'value': 'Mad Max: Fury Road'}, 'commentCount': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '739'}}

# %%
import rdflib 
g = rdflib.Graph()
qres = g.query(
    """
    SELECT *
    WHERE {
      SERVICE http://localhost:7200/repositories/movies{
        # ?s ?a ?o .
      }
    }
    LIMIT 3
    """
)

for row in qres:
    print(row.s)
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# <ipython-input-23-02ab8932c798> in <module>
#       1 import rdflib
#       2 g = rdflib.Graph()
# ----> 3 qres = g.query(
#       4     """
#       5     SELECT *
#
# c:\Users\Patrice\anaconda3\lib\site-packages\rdflib\graph.py in query(self, query_object, processor, result, initNs, initBindings, use_store_provided, **kwargs)
#    1387             processor = plugin.get(processor, query.Processor)(self)
#    1388
# -> 1389         return result(processor.query(query_object, initBindings, initNs, **kwargs))
#    1390
#    1391     def update(
#
# c:\Users\Patrice\anaconda3\lib\site-packages\rdflib\plugins\sparql\processor.py in query(self, strOrQuery, initBindings, initNs, base, DEBUG)
#      75
#      76         if not isinstance(strOrQuery, Query):
# ---> 77             parsetree = parseQuery(strOrQuery)
#      78             query = translateQuery(parsetree, base, initNs)
#      79         else:
#
# c:\Users\Patrice\anaconda3\lib\site-packages\rdflib\plugins\sparql\parser.py in parseQuery(q)
#    1534
#    1535     q = expandUnicodeEscapes(q)
# -> 1536     return Query.parseString(q, parseAll=True)
#    1537
#    1538
#
# c:\Users\Patrice\anaconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1953                 if getattr(exc, '__traceback__', None) is not None:
#    1954                     exc.__traceback__ = self._trim_traceback(exc.__traceback__)
# -> 1955                 raise exc
#    1956         else:
#    1957             return tokens
#
# c:\Users\Patrice\anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    2897         if instring[loc] == self.firstMatchChar:
#    2898             return loc + 1, self.match
# -> 2899         raise ParseException(instring, loc, self.errmsg, self)
#    2900
#    2901 _L = Literal
#
# ParseException: Expected {SelectQuery | ConstructQuery | DescribeQuery | AskQuery}, found 'S'  (at char 32), (line:4, col:7)
